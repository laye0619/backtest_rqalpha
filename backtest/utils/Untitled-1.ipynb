# %%
import tushare as ts
from backtest.utils.bt_analysis_helper import *
import dtale


ts.set_token('602e5ad960d66ab8b1f3c13b4fd746f5323ff808b0820768b02c6da3')
pro = ts.pro_api()

df = pro.index_daily(ts_code='000300.SH')
df = df[['trade_date', 'close']]
df = df.set_index('trade_date')

result_df = caculate_vo_ts(df)
result_df.dropna(how='any', inplace=True)
# Out:
# /home/coder/project/backtest_rqalpha/backtest/utils/bt_analysis_helper.py:55: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/coder/project/backtest_rqalpha/backtest/utils/bt_analysis_helper.py:55: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/coder/project/backtest_rqalpha/backtest/utils/bt_analysis_helper.py:55: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
dtale.show(result_df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://c7c45d691402:40000/dtale/iframe/3"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
